# %%
import pandas as pd
df = pd.read_csv('Catalog_v2.csv')

# %%
df.head()
# Out:
#   levelType                  code catalogType                  name  \
# 0  CATEGORY       Street Lighting     PRODUCT       Street Lighting
# 1  CATEGORY   Pedestrian Lighting     PRODUCT   Pedestrian Lighting
# 2  CATEGORY  Traffic Signal Poles     PRODUCT  Traffic Signal Poles
# 3  CATEGORY              Controls     PRODUCT              Controls
# 4  CATEGORY            Downlights     PRODUCT            Downlights
#
#                               description  \
# 0       Category code for Street Lighting
# 1   Category code for Pedestrian Lighting
# 2  Category code for Traffic Signal Poles
# 3              Category code for Controls
# 4            Category code for Downlights
#
#                                   sourceLink
# 0       http://lighttree.com/Street Lighting
# 1   http://lighttree.com/Pedestrian Lighting
# 2  http://lighttree.com/Traffic Signal Poles
# 3              http://lighttree.com/Controls
# 4            http://lighttree.com/Downlights

# %%
df.describe()
# Out:
#        levelType code catalogType name          description  \
# count         62   62          62   62                   62
# unique         4   50           2   50                   50
# top       FAMILY  All     PRODUCT  All  Family code for All
# freq          29    3          52    3                    3
#
#                       sourceLink
# count                         62
# unique                        50
# top     http://lighttree.com/All
# freq                           3

# %%
df.describe(include='all')
# Out:
#        levelType code catalogType name          description  \
# count         62   62          62   62                   62
# unique         4   50           2   50                   50
# top       FAMILY  All     PRODUCT  All  Family code for All
# freq          29    3          52    3                    3
#
#                       sourceLink
# count                         62
# unique                        50
# top     http://lighttree.com/All
# freq                           3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   levelType    62 non-null     object
#  1   code         62 non-null     object
#  2   catalogType  62 non-null     object
#  3   name         62 non-null     object
#  4   description  62 non-null     object
#  5   sourceLink   62 non-null     object
# dtypes: object(6)
# memory usage: 3.0+ KB

# %%
import numpy as np

# %%
# Encode the 'name' column as integers
df['name'] = df['name'].astype('category').cat.codes.astype(np.int8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   levelType    62 non-null     object
#  1   code         62 non-null     object
#  2   catalogType  62 non-null     object
#  3   name         62 non-null     int8
#  4   description  62 non-null     object
#  5   sourceLink   62 non-null     object
# dtypes: int8(1), object(5)
# memory usage: 2.6+ KB

# %%
filtro = df['name'] >= 10
df[filtro]
# Out:
#    levelType                          code catalogType  name  \
# 0   CATEGORY               Street Lighting     PRODUCT    42
# 1   CATEGORY           Pedestrian Lighting     PRODUCT    29
# 2   CATEGORY          Traffic Signal Poles     PRODUCT    45
# 3   CATEGORY                      Controls     PRODUCT    14
# 4   CATEGORY                    Downlights     PRODUCT    15
# 5   CATEGORY           Retrofit Downlights     PRODUCT    33
# 8   CATEGORY                   Controllers     PRODUCT    13
# 9   CATEGORY                    Enclosures     PRODUCT    16
# 10  CATEGORY       High Voltage Electrical     PRODUCT    21
# 11  CATEGORY                        Lenses     PRODUCT    24
# 12  CATEGORY                     Luminaire     PRODUCT    25
# 13  CATEGORY                   Mechanicals     PRODUCT    26
# 14  CATEGORY               Primary Chassis     PRODUCT    30
# 15  CATEGORY            Primary Foundation     PRODUCT    31
# ...

# %%
df.head()
# Out:
#   levelType                  code catalogType  name  \
# 0  CATEGORY       Street Lighting     PRODUCT    42
# 1  CATEGORY   Pedestrian Lighting     PRODUCT    29
# 2  CATEGORY  Traffic Signal Poles     PRODUCT    45
# 3  CATEGORY              Controls     PRODUCT    14
# 4  CATEGORY            Downlights     PRODUCT    15
#
#                               description  \
# 0       Category code for Street Lighting
# 1   Category code for Pedestrian Lighting
# 2  Category code for Traffic Signal Poles
# 3              Category code for Controls
# 4            Category code for Downlights
#
#                                   sourceLink
# 0       http://lighttree.com/Street Lighting
# 1   http://lighttree.com/Pedestrian Lighting
# 2  http://lighttree.com/Traffic Signal Poles
# 3              http://lighttree.com/Controls
# 4            http://lighttree.com/Downlights

# %%
df
# Out:
#    levelType                  code catalogType  name  \
# 0   CATEGORY       Street Lighting     PRODUCT    42
# 1   CATEGORY   Pedestrian Lighting     PRODUCT    29
# 2   CATEGORY  Traffic Signal Poles     PRODUCT    45
# 3   CATEGORY              Controls     PRODUCT    14
# 4   CATEGORY            Downlights     PRODUCT    15
# ..       ...                   ...         ...   ...
# 57  CATEGORY             Luminaire        ITEM    25
# 58  CATEGORY           Mechanicals        ITEM    26
# 59  CATEGORY       Primary Chassis        ITEM    30
# 60  CATEGORY    Primary Foundation        ITEM    31
# 61  CATEGORY     Secondary Chassis        ITEM    38
#
#                                description  \
# 0        Category code for Street Lighting
# 1    Category code for Pedestrian Lighting
# 2   Category code for Traffic Signal Poles
# 3               Category code for Controls
# 4             Category code for Downlights
# ..                                     ...
# ...

# %%
df[['code', 'name']]
# Out:
#                     code  name
# 0        Street Lighting    42
# 1    Pedestrian Lighting    29
# 2   Traffic Signal Poles    45
# 3               Controls    14
# 4             Downlights    15
# ..                   ...   ...
# 57             Luminaire    25
# 58           Mechanicals    26
# 59       Primary Chassis    30
# 60    Primary Foundation    31
# 61     Secondary Chassis    38
#
# [62 rows x 2 columns]

# %%
df['catalogType']=='ITEM'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57     True
# 58     True
# 59     True
# 60     True
# 61     True
# Name: catalogType, Length: 62, dtype: bool

# %%
df[(df['catalogType']=='ITEM')]
# Out:
#    levelType                     code catalogType  name  \
# 52  CATEGORY                    Bulbs        ITEM     8
# 53  CATEGORY              Controllers        ITEM    13
# 54  CATEGORY               Enclosures        ITEM    16
# 55  CATEGORY  High Voltage Electrical        ITEM    21
# 56  CATEGORY                   Lenses        ITEM    24
# 57  CATEGORY                Luminaire        ITEM    25
# 58  CATEGORY              Mechanicals        ITEM    26
# 59  CATEGORY          Primary Chassis        ITEM    30
# 60  CATEGORY       Primary Foundation        ITEM    31
# 61  CATEGORY        Secondary Chassis        ITEM    38
#
#                                   description  \
# 52                    Category code for Bulbs
# 53              Category code for Controllers
# 54               Category code for Enclosures
# 55  Category code for High Voltage Electrical
# 56                   Category code for Lenses
# 57                Category code for Luminaire
# ...

# %%
df[~(df['catalogType']=='ITEM')]
# Out:
#    levelType                          code catalogType  name  \
# 0   CATEGORY               Street Lighting     PRODUCT    42
# 1   CATEGORY           Pedestrian Lighting     PRODUCT    29
# 2   CATEGORY          Traffic Signal Poles     PRODUCT    45
# 3   CATEGORY                      Controls     PRODUCT    14
# 4   CATEGORY                    Downlights     PRODUCT    15
# 5   CATEGORY           Retrofit Downlights     PRODUCT    33
# 6   CATEGORY                       Ambient     PRODUCT     5
# 7   CATEGORY                         Bulbs     PRODUCT     8
# 8   CATEGORY                   Controllers     PRODUCT    13
# 9   CATEGORY                    Enclosures     PRODUCT    16
# 10  CATEGORY       High Voltage Electrical     PRODUCT    21
# 11  CATEGORY                        Lenses     PRODUCT    24
# 12  CATEGORY                     Luminaire     PRODUCT    25
# 13  CATEGORY                   Mechanicals     PRODUCT    26
# ...

# %%
df.iloc[0:5, 0:2]
# Out:
#   levelType                  code
# 0  CATEGORY       Street Lighting
# 1  CATEGORY   Pedestrian Lighting
# 2  CATEGORY  Traffic Signal Poles
# 3  CATEGORY              Controls
# 4  CATEGORY            Downlights

# %%
df2 = pd.read_csv('Inventory_v2.csv')

# %%
df2.head()
# Out:
#   product.partNumber location.locationIdentifier inventoryType  quantity  \
# 0         PS-SL-A287                        LT-1       PRODUCT        25
# 1         PS-SL-A288                        LT-1       PRODUCT        20
# 2         PS-SL-H309                        LT-1       PRODUCT         3
# 3         PS-SL-H310                        LT-1       PRODUCT        35
# 4         PS-SL-F342                        LT-1       PRODUCT        43
#
#   quantityUnits    value valueCurrency  reservationOrders  daysOfSupply  \
# 0            EA  31250.0           USD                  2            19
# 1            EA  25000.0           USD                  2            35
# 2            EA   3750.0           USD                  2            14
# 3            EA  43750.0           USD                  2            16
# 4            EA  53750.0           USD                  2            42
#
#    shelfLife  ...  quantityUpperThreshold  quantityLowerThreshold  \
# ...

# %%
# Para exportar el data frame a un archivo CSV
df.to_csv('new_catalog.csv', index=False)

# %%
df.drop(columns=['name'])
# Out:
#    levelType                  code catalogType  \
# 0   CATEGORY       Street Lighting     PRODUCT
# 1   CATEGORY   Pedestrian Lighting     PRODUCT
# 2   CATEGORY  Traffic Signal Poles     PRODUCT
# 3   CATEGORY              Controls     PRODUCT
# 4   CATEGORY            Downlights     PRODUCT
# ..       ...                   ...         ...
# 57  CATEGORY             Luminaire        ITEM
# 58  CATEGORY           Mechanicals        ITEM
# 59  CATEGORY       Primary Chassis        ITEM
# 60  CATEGORY    Primary Foundation        ITEM
# 61  CATEGORY     Secondary Chassis        ITEM
#
#                                description  \
# 0        Category code for Street Lighting
# 1    Category code for Pedestrian Lighting
# 2   Category code for Traffic Signal Poles
# 3               Category code for Controls
# 4             Category code for Downlights
# ..                                     ...
# 57             Category code for Luminaire
# ...

# %%
# algoritmos ML
# datos de entrada: X(una o mas variables)
X=df2[['quantity']]
X
# Out:
#      quantity
# 0          25
# 1          20
# 2           3
# 3          35
# 4          43
# ..        ...
# 149       118
# 150       323
# 151       273
# 152       259
# 153        27
#
# [154 rows x 1 columns]

# %%
# datas de salida: y(una o mas variables)
y=df2[['value']]
y
# Out:
#         value
# 0     31250.0
# 1     25000.0
# 2      3750.0
# 3     43750.0
# 4     53750.0
# ..        ...
# 149  151866.0
# 150  470288.0
# 151  227409.0
# 152  267288.0
# 153   26352.0
#
# [154 rows x 1 columns]

# %%
# renombrar columnas
df2.rename(columns={'quantity': 'cantidad', 'value': 'valor'}, inplace=True)
df2.head()
# Out:
#   product.partNumber location.locationIdentifier inventoryType  cantidad  \
# 0         PS-SL-A287                        LT-1       PRODUCT        25
# 1         PS-SL-A288                        LT-1       PRODUCT        20
# 2         PS-SL-H309                        LT-1       PRODUCT         3
# 3         PS-SL-H310                        LT-1       PRODUCT        35
# 4         PS-SL-F342                        LT-1       PRODUCT        43
#
#   quantityUnits    valor valueCurrency  reservationOrders  daysOfSupply  \
# 0            EA  31250.0           USD                  2            19
# 1            EA  25000.0           USD                  2            35
# 2            EA   3750.0           USD                  2            14
# 3            EA  43750.0           USD                  2            16
# 4            EA  53750.0           USD                  2            42
#
#    shelfLife  ...  quantityUpperThreshold  quantityLowerThreshold  \
# ...

# %%
# deteccion de valores nulos
df2.isna().sum()
# Out:
# product.partNumber               0
# location.locationIdentifier      0
# inventoryType                    0
# cantidad                         0
# quantityUnits                    0
# valor                            0
# valueCurrency                    0
# reservationOrders                0
# daysOfSupply                     0
# shelfLife                        0
# reorderLevel                     0
# expectedLeadTime                 0
# quantityUpperThreshold           0
# quantityLowerThreshold           0
# daysOfSupplyUpperThreshold       0
# daysOfSupplyLowerThreshold       0
# expiringThreshold              154
# plannerCode                      0
# velocityCode                     0
# inventoryParentType              0
# class                            0
# segment                         76
# dtype: int64

# %%
# manejar valorres nulos
# Opcion 1 eliminar filas con valores nulos. solo si se tiene pocos valores nulos
# df2.dropna(inplace=True)
# Opcion 2 reemplazar valores nulos por un valor especifico o por la media de la columna
# df2.fillna(df2.mean(), inplace=True) #reemplazar por la media
# df2.fillna(0, inplace=True) #reemplazar por 0

# %% [markdown]
# **Manejar valorres nulos**
# - Opcion 1 eliminar filas con valores nulos. solo si se tiene pocos valores nulos
#     > df2.dropna(inplace=True)
# - Opcion 2 reemplazar valores nulos por un valor especifico o por la media de la columna
#     > df2.fillna(df2.mean(), inplace=True) -> reemplazar por la media
#     > df2.fillna(0, inplace=True) -> reemplazar por 0
