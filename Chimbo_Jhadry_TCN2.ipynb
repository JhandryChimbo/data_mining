# %% [markdown]
# # Regresión Polinomial en Machine Learning
#  Nombre: Jhanry Santiago Chimbo Rivera
#  Carrera: Ingeniería en Computación
#  Trabajo en Clase N°2 - Abril-Agosto 2025
#
#  📚 Objetivo: Aplicar la técnica de regresión polinomial para modelar datos no lineales usando scikit-learn.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 1. Generar un conjuntod de datos sintéticos no lineales
X = np.random.rand(200,1)*2
y = 3-1.5*X+0.1*X**2-0.01*X**3 + 1.17*X**4 + 2*X**5 + np.random.rand(200,1)*12

# %%
# 2. Visualizar los datos
plt.scatter(X, y,)
plt.title('Datos Sintéticos No Lineales')
plt.xlabel('X')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
# 3. Transforma las caracteristicas de terminos polinomiales (Grado 5)
poly = PolynomialFeatures(degree=5)
X_poly = poly.fit_transform(X)

# %%
# 4. Ajustar el modelo de regresión 
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# 5. Coeficientes de la ecuacion
print('Coeficientes:', model.coef_)
print('Intercepto:', model.intercept_)
coefficients = model.coef_.flatten() 
print(f"y = {model.intercept_[0]:.2f} + {coefficients[1]:.2f}*X + {coefficients[2]:.2f}*X^2 + {coefficients[3]:.2f}*X^3 + {coefficients[4]:.2f}*X^4 + {coefficients[5]:.2f}*X^5")
# Out:
# Coeficientes: [[  0.         -20.36016333  62.65403849 -86.72105636  51.1292174
#    -8.03204314]]
# Intercepto: [11.72339005]
# y = 11.72 + -20.36*X + 62.65*X^2 + -86.72*X^3 + 51.13*X^4 + -8.03*X^5

# %%
# 6. Predicciones
y_pred = model.predict(X_poly)

# %%
# 7. Evaluar el modelo
mse = mean_squared_error(y, y_pred)
print('Error Cuadrático Medio:', mse)
# Out:
# Error Cuadrático Medio: 11.270754037328729

# %%
# 8. Graficar los resultados
sorted_indices = X[:, 0].argsort()
X_sorted = X[sorted_indices]
y_sorted = y_pred[sorted_indices]

plt.scatter(X, y, label='Datos reales')      
plt.plot(X_sorted, y_sorted,color = "red", label='Modelo')
plt.title('Datos Sintéticos No Lineales y Modelo Polinomial')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
